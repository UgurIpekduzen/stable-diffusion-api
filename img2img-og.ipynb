# %% [markdown]
# # Text-guided image-to-image generation

# %% [markdown]
# The [StableDiffusionImg2ImgPipeline](https://huggingface.co/docs/diffusers/main/en/api/pipelines/stable_diffusion/img2img#diffusers.StableDiffusionImg2ImgPipeline) lets you pass a text prompt and an initial image to condition the generation of new images.
#
# Before you begin, make sure you have all the necessary libraries installed:

# %%
# uncomment to install the necessary libraries in Colab
# !pip install diffusers transformers ftfy accelerate
# Out:
# Requirement already satisfied: diffusers in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (0.21.4)
# Requirement already satisfied: transformers in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (4.34.1)
# Requirement already satisfied: ftfy in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (6.1.1)
# Requirement already satisfied: accelerate in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (0.24.1)
# Requirement already satisfied: Pillow in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from diffusers) (10.1.0)
# Requirement already satisfied: filelock in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from diffusers) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.13.2 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from diffusers) (0.17.3)
# Requirement already satisfied: importlib-metadata in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from diffusers) (6.8.0)
# Requirement already satisfied: numpy in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from diffusers) (1.26.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from diffusers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from diffusers) (0.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from transformers) (0.14.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from ftfy) (0.2.9)
# Requirement already satisfied: psutil in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from accelerate) (5.9.6)
# Requirement already satisfied: torch>=1.10.0 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: fsspec in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (4.8.0)
# Requirement already satisfied: sympy in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: colorama in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from importlib-metadata->diffusers) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from requests->diffusers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from requests->diffusers) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\documents\github\stable-diffusion-api\venv\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %% [markdown]
# Get started by creating a [StableDiffusionImg2ImgPipeline](https://huggingface.co/docs/diffusers/main/en/api/pipelines/stable_diffusion/img2img#diffusers.StableDiffusionImg2ImgPipeline) with a pretrained Stable Diffusion model like [`nitrosocke/Ghibli-Diffusion`](https://huggingface.co/nitrosocke/Ghibli-Diffusion).

# %%
import torch
import requests
from PIL import Image
from io import BytesIO
from diffusers import StableDiffusionImg2ImgPipeline

device = "cuda"
pipe = StableDiffusionImg2ImgPipeline.from_pretrained("nitrosocke/Ghibli-Diffusion", torch_dtype=torch.float32).to(
    device
)
# Out:
# text_encoder\model.safetensors not found
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.

# %% [markdown]
# Download and preprocess an initial image so you can pass it to the pipeline:

# %%
url = "https://raw.githubusercontent.com/CompVis/stable-diffusion/main/assets/stable-samples/img2img/sketch-mountains-input.jpg"

response = requests.get(url)
init_image = Image.open(BytesIO(response.content)).convert("RGB")
init_image.thumbnail((768, 768))
init_image
# Out:
# <PIL.Image.Image image mode=RGB size=768x384>

# %% [markdown]
# <div class="flex justify-center">
#     <img src="https://huggingface.co/datasets/YiYiXu/test-doc-assets/resolve/main/image_2_image_using_diffusers_cell_8_output_0.jpeg"/>
# </div>
#
# <Tip>
#
# 💡 `strength` is a value between 0.0 and 1.0 that controls the amount of noise added to the input image. Values that approach 1.0 allow for lots of variations but will also produce images that are not semantically consistent with the input.
#
# </Tip>
#
# Define the prompt (for this checkpoint finetuned on Ghibli-style art, you need to prefix the prompt with the `ghibli style` tokens) and run the pipeline:

# %%
prompt = "ghibli style, a fantasy landscape with castles"
generator = torch.Generator(device=device).manual_seed(1024)
image = pipe(prompt=prompt, image=init_image, strength=0.75, guidance_scale=7.5, generator=generator).images[0]
image
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x384>

# %% [markdown]
# <div class="flex justify-center">
#     <img src="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/diffusers/ghibli-castles.png"/>
# </div>
#
# You can also try experimenting with a different scheduler to see how that affects the output:

# %%
from diffusers import LMSDiscreteScheduler

lms = LMSDiscreteScheduler.from_config(pipe.scheduler.config)
pipe.scheduler = lms
generator = torch.Generator(device=device).manual_seed(1024)
image = pipe(prompt=prompt, image=init_image, strength=0.75, guidance_scale=7.5, generator=generator).images[0]
image
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x384>

# %% [markdown]
# <div class="flex justify-center">
#     <img src="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/diffusers/lms-ghibli.png"/>
# </div>
#
# Check out the Spaces below, and try generating images with different values for `strength`. You'll notice that using lower values for `strength` produces images that are more similar to the original image.
#
# Feel free to also switch the scheduler to the [LMSDiscreteScheduler](https://huggingface.co/docs/diffusers/main/en/api/schedulers/lms_discrete#diffusers.LMSDiscreteScheduler) and see how that affects the output.
#
# <iframe
# 	src="https://stevhliu-ghibli-img2img.hf.space"
# 	frameborder="0"
# 	width="850"
# 	height="500"
# ></iframe>
